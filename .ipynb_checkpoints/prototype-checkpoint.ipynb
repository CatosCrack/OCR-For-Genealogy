# %%
from google.cloud import documentai_v1 as documentai
from google.oauth2 import service_account
from database import Database

db = Database()

# Base processor data
project_id = "genealogy-ocr-index"
location = "us"
processor_id = "4cb2ae40b145c48"

class ocr_engine:
    def __init__(self) -> None:

        # Create a client
        cred = service_account.Credentials.from_service_account_file("secrets/docai_credentials.json")
        self.__client = documentai.DocumentProcessorServiceClient(
            credentials=cred,
            client_options={"api_endpoint": f"{location}-documentai.googleapis.com"}
        )

        # Get the processor
        self.__processor = self.__client.processor_path(project=project_id, location=location, processor=processor_id)

    def process_documents(self):

        # Get image from URL
        uris = db.storage_get_images()

        # Get extension of images to set correct mime type
        extension = uris[2][-3:]
        if "jpg" in extension:
            extension = "jpeg"
        elif "png" in extension:
            extension = "png"

        # Create a raw document object
        document = documentai.GcsDocument(gcs_uri=uris[2], mime_type=f"image/{extension}")

        # Create API request
        request = documentai.ProcessRequest(name=self.__processor, 
                                            gcs_document=document,
                                            process_options={"ocr_config": {
                                                "hints": {"language_hints": "es"}
                                                }
                                            })

        # Get result
        result = self.__client.process_document(request=request)
        return result.document
# Out:
# App initialized

# %%
engine = ocr_engine()

# %%
result = engine.process_documents()

# %%
text = result.text

# %%
document_text = ""
i = 0
while i < len(text):
    if text[i] == "-" and text[i+1] == "\n":
        document_text += ""
        i += 2
    elif text[i] == "\n" and text[i-1] != "":
        document_text += " "
        i += 1
    else:
        document_text += text[i]
        i += 1

# %%
text
# Out:
# "648\n-62-\nen el citio de la Loma donde se divide para Chiscote, la que hubo\nen el reparto del resguardo de Guacamayas.-\n334)--Esc .292-- El Cocuy 25 de julio de 1858- Eleuterio y Ju-\nlian Patricio venden a Joaquín 1 aría Espinel el derecho y acción\nque a cada uno le corresponde en las tierras del Alizal, ycortade\nra vereda do. laa Tapias jurisdicción de Chiscas, las que hubieron\nen el reparto del resguardo de índíjenas de dicho Chiscas.-------\n355)--Esc #293-- El Cocuy 25 de julio de 1858 Juan Crisostomo Ro\ndríguez, vendor a Gavino Largo un pedazo de tierra en el sitio de\nBocachica jurisdicción de la Capilla; el que hubo por compra\nΠ\nJavier Solano y Gregorio Murillo\no a su pr\n536)--Eso . 294-- ElCocuy 25 de julio de 1858-- Con éste Número\ny en la fecha queda protocolado el documento que Antonio José de\nHerrera otorgó a Mateo Marón y Francisco Javier Leal vendiendoles\nuna estancia en el páramo del Contento jurisdicción de Chiscas y\nGuicon\n357)--Folio 512-- El Cocuy 1° de setiembre de 1807-- Antonio José\nde Herrera, vende a José Matero Burón y Francisco Javier Leal, una\nestancia de tierra en los piramos que sitan Contento jurisdicción\nde ésta parroquia la que hubo de su difunto padre Antonio de Herre\nza Lovatón (este documento se encuentra muy comido a las orillas\ny por lo mismo le faltan muchas palabras\n338)--Esc #295-- El Cocuy 25 de julio de 1858-- Juan Toure,y Mi\nguel Chacón venden a Cruz Barrera, una suerte de tierra en el si\ntio de la hoya de Chacón juridicción de Guacmayas, las que hubier\nron por compra a Domingo Cuchavara\n339)--Esc .296-- El Cocuy 26 de julio de 1858--Cruz Barrera,\nvende a Jesús Patiño, un pedazo de tierra en el sitio de la Hoyn d\nChacones, jurisdicción de Guacamyas. el que hubo por compra a Je\nsús Támara, y Miguel Chacón\n340)--Esc #. 297-- El Cocuy 26 de julio de 1858--Camila Muñoz, v\nvende a Antonio Herrera un derecho de tierra en el sitio del en\ncerrado de los Carreños\n'\njurisdicción del Espino el mismo que le\n"

# %%
print(document_text)
# Out:
# 648 -62en el citio de la Loma donde se divide para Chiscote, la que hubo en el reparto del resguardo de Guacamayas.334)--Esc .292-- El Cocuy 25 de julio de 1858- Eleuterio y Julian Patricio venden a Joaquín 1 aría Espinel el derecho y acción que a cada uno le corresponde en las tierras del Alizal, ycortade ra vereda do. laa Tapias jurisdicción de Chiscas, las que hubieron en el reparto del resguardo de índíjenas de dicho Chiscas.------355)--Esc #293-- El Cocuy 25 de julio de 1858 Juan Crisostomo Ro dríguez, vendor a Gavino Largo un pedazo de tierra en el sitio de Bocachica jurisdicción de la Capilla; el que hubo por compra Π Javier Solano y Gregorio Murillo o a su pr 536)--Eso . 294-- ElCocuy 25 de julio de 1858-- Con éste Número y en la fecha queda protocolado el documento que Antonio José de Herrera otorgó a Mateo Marón y Francisco Javier Leal vendiendoles una estancia en el páramo del Contento jurisdicción de Chiscas y Guicon 357)--Folio 512-- El Cocuy 1° de setiembre de 1807-- Antonio José de Herrera, vende a José Matero Burón y Francisco Javier Leal, una estancia de tierra en los piramos que sitan Contento jurisdicción de ésta parroquia la que hubo de su difunto padre Antonio de Herre za Lovatón (este documento se encuentra muy comido a las orillas y por lo mismo le faltan muchas palabras 338)--Esc #295-- El Cocuy 25 de julio de 1858-- Juan Toure,y Mi guel Chacón venden a Cruz Barrera, una suerte de tierra en el si tio de la hoya de Chacón juridicción de Guacmayas, las que hubier ron por compra a Domingo Cuchavara 339)--Esc .296-- El Cocuy 26 de julio de 1858--Cruz Barrera, vende a Jesús Patiño, un pedazo de tierra en el sitio de la Hoyn d Chacones, jurisdicción de Guacamyas. el que hubo por compra a Je sús Támara, y Miguel Chacón 340)--Esc #. 297-- El Cocuy 26 de julio de 1858--Camila Muñoz, v vende a Antonio Herrera un derecho de tierra en el sitio del en cerrado de los Carreños ' jurisdicción del Espino el mismo que le

# %%
# Open name and last name files to add them to the model's entity ruler
import csv
names = []
last_names = []

with open('ner_data/first_names_processed.csv', 'r', newline="") as file:
    reader = csv.reader(file, delimiter=",")
    for row in reader:
        names.append(row[0])

with open('ner_data/last_names_processed.csv', 'r', newline='') as file:
    reader = csv.reader(file, delimiter=",")
    for row in reader:
        last_names.append(row[0])

# %%
# Load Spanish model
import spacy
nlp = spacy.load("es_core_news_lg")

# %%
# Add names and last names to entity ruler
ruler = nlp.add_pipe("entity_ruler", after="ner")

# %%
# Create patterns
patterns = []
for name in names:
    patterns.append({
        "label":"FIRST_NAME",
        "pattern": [{"LOWER":name.lower()}]
    })

for name in last_names:
    patterns.append({
        "label":"LAST_NAME",
        "pattern": [{"LOWER":name.lower()}]
    })

# Add patterns to pipeline
ruler.add_patterns(patterns)

# %%
patterns
# Out:
# [{'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Antonio'}, {'LOWER': 'antonio'}, {'LENGTH': 7}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Manuel'}, {'LOWER': 'manuel'}, {'LENGTH': 6}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Jose'}, {'LOWER': 'jose'}, {'LENGTH': 4}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Francisco'}, {'LOWER': 'francisco'}, {'LENGTH': 9}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'David'}, {'LOWER': 'david'}, {'LENGTH': 5}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Juan'}, {'LOWER': 'juan'}, {'LENGTH': 4}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Javier'}, {'LOWER': 'javier'}, {'LENGTH': 6}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Daniel'}, {'LOWER': 'daniel'}, {'LENGTH': 6}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Jose Antonio'},
#    {'LOWER': 'jose antonio'},
#    {'LENGTH': 12}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Francisco Javier'},
#    {'LOWER': 'francisco javier'},
#    {'LENGTH': 16}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Jose Luis'}, {'LOWER': 'jose luis'}, {'LENGTH': 9}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Carlos'}, {'LOWER': 'carlos'}, {'LENGTH': 6}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Alejandro'}, {'LOWER': 'alejandro'}, {'LENGTH': 9}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Jesus'}, {'LOWER': 'jesus'}, {'LENGTH': 5}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Jose Manuel'},
#    {'LOWER': 'jose manuel'},
#    {'LENGTH': 11}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Miguel'}, {'LOWER': 'miguel'}, {'LENGTH': 6}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Miguel Angel'},
#    {'LOWER': 'miguel angel'},
#    {'LENGTH': 12}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Pablo'}, {'LOWER': 'pablo'}, {'LENGTH': 5}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Rafael'}, {'LOWER': 'rafael'}, {'LENGTH': 6}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Sergio'}, {'LOWER': 'sergio'}, {'LENGTH': 6}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Angel'}, {'LOWER': 'angel'}, {'LENGTH': 5}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Pedro'}, {'LOWER': 'pedro'}, {'LENGTH': 5}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Fernando'}, {'LOWER': 'fernando'}, {'LENGTH': 8}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Jorge'}, {'LOWER': 'jorge'}, {'LENGTH': 5}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Jose Maria'},
#    {'LOWER': 'jose maria'},
#    {'LENGTH': 10}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Luis'}, {'LOWER': 'luis'}, {'LENGTH': 4}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Alberto'}, {'LOWER': 'alberto'}, {'LENGTH': 7}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Alvaro'}, {'LOWER': 'alvaro'}, {'LENGTH': 6}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Adrian'}, {'LOWER': 'adrian'}, {'LENGTH': 6}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Juan Carlos'},
#    {'LOWER': 'juan carlos'},
#    {'LENGTH': 11}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Diego'}, {'LOWER': 'diego'}, {'LENGTH': 5}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Juan Jose'}, {'LOWER': 'juan jose'}, {'LENGTH': 9}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Raul'}, {'LOWER': 'raul'}, {'LENGTH': 4}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Ivan'}, {'LOWER': 'ivan'}, {'LENGTH': 4}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Ruben'}, {'LOWER': 'ruben'}, {'LENGTH': 5}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Juan Antonio'},
#    {'LOWER': 'juan antonio'},
#    {'LENGTH': 12}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Oscar'}, {'LOWER': 'oscar'}, {'LENGTH': 5}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Enrique'}, {'LOWER': 'enrique'}, {'LENGTH': 7}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Juan Manuel'},
#    {'LOWER': 'juan manuel'},
#    {'LENGTH': 11}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Andres'}, {'LOWER': 'andres'}, {'LENGTH': 6}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Ramon'}, {'LOWER': 'ramon'}, {'LENGTH': 5}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Mario'}, {'LOWER': 'mario'}, {'LENGTH': 5}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Santiago'}, {'LOWER': 'santiago'}, {'LENGTH': 8}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Victor'}, {'LOWER': 'victor'}, {'LENGTH': 6}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Vicente'}, {'LOWER': 'vicente'}, {'LENGTH': 7}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Joaquin'}, {'LOWER': 'joaquin'}, {'LENGTH': 7}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Eduardo'}, {'LOWER': 'eduardo'}, {'LENGTH': 7}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Marcos'}, {'LOWER': 'marcos'}, {'LENGTH': 6}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Roberto'}, {'LOWER': 'roberto'}, {'LENGTH': 7}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Hugo'}, {'LOWER': 'hugo'}, {'LENGTH': 4}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Jaime'}, {'LOWER': 'jaime'}, {'LENGTH': 5}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Francisco Jose'},
#    {'LOWER': 'francisco jose'},
#    {'LENGTH': 14}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Ignacio'}, {'LOWER': 'ignacio'}, {'LENGTH': 7}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Jordi'}, {'LOWER': 'jordi'}, {'LENGTH': 5}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Alfonso'}, {'LOWER': 'alfonso'}, {'LENGTH': 7}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Ricardo'}, {'LOWER': 'ricardo'}, {'LENGTH': 7}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Mohamed'}, {'LOWER': 'mohamed'}, {'LENGTH': 7}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Salvador'}, {'LOWER': 'salvador'}, {'LENGTH': 8}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Marc'}, {'LOWER': 'marc'}, {'LENGTH': 4}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Martin'}, {'LOWER': 'martin'}, {'LENGTH': 6}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Guillermo'}, {'LOWER': 'guillermo'}, {'LENGTH': 9}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Gabriel'}, {'LOWER': 'gabriel'}, {'LENGTH': 7}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Gonzalo'}, {'LOWER': 'gonzalo'}, {'LENGTH': 7}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Emilio'}, {'LOWER': 'emilio'}, {'LENGTH': 6}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Jose Miguel'},
#    {'LOWER': 'jose miguel'},
#    {'LENGTH': 11}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Nicolas'}, {'LOWER': 'nicolas'}, {'LENGTH': 7}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Julio'}, {'LOWER': 'julio'}, {'LENGTH': 5}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Julian'}, {'LOWER': 'julian'}, {'LENGTH': 6}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Tomas'}, {'LOWER': 'tomas'}, {'LENGTH': 5}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Lucas'}, {'LOWER': 'lucas'}, {'LENGTH': 5}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Samuel'}, {'LOWER': 'samuel'}, {'LENGTH': 6}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Agustin'}, {'LOWER': 'agustin'}, {'LENGTH': 7}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Ismael'}, {'LOWER': 'ismael'}, {'LENGTH': 6}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Jose Ramon'},
#    {'LOWER': 'jose ramon'},
#    {'LENGTH': 10}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Cristian'}, {'LOWER': 'cristian'}, {'LENGTH': 8}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Joan'}, {'LOWER': 'joan'}, {'LENGTH': 4}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Aitor'}, {'LOWER': 'aitor'}, {'LENGTH': 5}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Hector'}, {'LOWER': 'hector'}, {'LENGTH': 6}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Felix'}, {'LOWER': 'felix'}, {'LENGTH': 5}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Alex'}, {'LOWER': 'alex'}, {'LENGTH': 4}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Iker'}, {'LOWER': 'iker'}, {'LENGTH': 4}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Mateo'}, {'LOWER': 'mateo'}, {'LENGTH': 5}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Juan Francisco'},
#    {'LOWER': 'juan francisco'},
#    {'LENGTH': 14}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Jose Carlos'},
#    {'LOWER': 'jose carlos'},
#    {'LENGTH': 11}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Sebastian'}, {'LOWER': 'sebastian'}, {'LENGTH': 9}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Cesar'}, {'LOWER': 'cesar'}, {'LENGTH': 5}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Rodrigo'}, {'LOWER': 'rodrigo'}, {'LENGTH': 7}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Josep'}, {'LOWER': 'josep'}, {'LENGTH': 5}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Alfredo'}, {'LOWER': 'alfredo'}, {'LENGTH': 7}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Jose Angel'},
#    {'LOWER': 'jose angel'},
#    {'LENGTH': 10}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Mariano'}, {'LOWER': 'mariano'}, {'LENGTH': 7}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Victor Manuel'},
#    {'LOWER': 'victor manuel'},
#    {'LENGTH': 13}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Domingo'}, {'LOWER': 'domingo'}, {'LENGTH': 7}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Jose Ignacio'},
#    {'LOWER': 'jose ignacio'},
#    {'LENGTH': 12}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Felipe'}, {'LOWER': 'felipe'}, {'LENGTH': 6}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Luis Miguel'},
#    {'LOWER': 'luis miguel'},
#    {'LENGTH': 11}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Pau'}, {'LOWER': 'pau'}, {'LENGTH': 3}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Jose Francisco'},
#    {'LOWER': 'jose francisco'},
#    {'LENGTH': 14}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Xavier'}, {'LOWER': 'xavier'}, {'LENGTH': 6}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Albert'}, {'LOWER': 'albert'}, {'LENGTH': 6}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Juan Luis'}, {'LOWER': 'juan luis'}, {'LENGTH': 9}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Izan'}, {'LOWER': 'izan'}, {'LENGTH': 4}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Aaron'}, {'LOWER': 'aaron'}, {'LENGTH': 5}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Mohammed'}, {'LOWER': 'mohammed'}, {'LENGTH': 8}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Eric'}, {'LOWER': 'eric'}, {'LENGTH': 4}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Leo'}, {'LOWER': 'leo'}, {'LENGTH': 3}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Antonio Jose'},
#    {'LOWER': 'antonio jose'},
#    {'LENGTH': 12}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Borja'}, {'LOWER': 'borja'}, {'LENGTH': 5}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Lorenzo'}, {'LOWER': 'lorenzo'}, {'LENGTH': 7}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Gregorio'}, {'LOWER': 'gregorio'}, {'LENGTH': 8}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Arturo'}, {'LOWER': 'arturo'}, {'LENGTH': 6}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Esteban'}, {'LOWER': 'esteban'}, {'LENGTH': 7}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Bruno'}, {'LOWER': 'bruno'}, {'LENGTH': 5}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Joel'}, {'LOWER': 'joel'}, {'LENGTH': 4}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Isaac'}, {'LOWER': 'isaac'}, {'LENGTH': 5}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Cristobal'}, {'LOWER': 'cristobal'}, {'LENGTH': 9}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Dario'}, {'LOWER': 'dario'}, {'LENGTH': 5}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Asier'}, {'LOWER': 'asier'}, {'LENGTH': 5}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Marco'}, {'LOWER': 'marco'}, {'LENGTH': 5}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Jose Javier'},
#    {'LOWER': 'jose javier'},
#    {'LENGTH': 11}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Antonio Jesus'},
#    {'LOWER': 'antonio jesus'},
#    {'LENGTH': 13}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Juan Miguel'},
#    {'LOWER': 'juan miguel'},
#    {'LENGTH': 11}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Francisco Manuel'},
#    {'LOWER': 'francisco manuel'},
#    {'LENGTH': 16}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Unai'}, {'LOWER': 'unai'}, {'LENGTH': 4}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Jesus Maria'},
#    {'LOWER': 'jesus maria'},
#    {'LENGTH': 11}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Abel'}, {'LOWER': 'abel'}, {'LENGTH': 4}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Ahmed'}, {'LOWER': 'ahmed'}, {'LENGTH': 5}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Jaume'}, {'LOWER': 'jaume'}, {'LENGTH': 5}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Eugenio'}, {'LOWER': 'eugenio'}, {'LENGTH': 7}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Jonathan'}, {'LOWER': 'jonathan'}, {'LENGTH': 8}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'German'}, {'LOWER': 'german'}, {'LENGTH': 6}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Mikel'}, {'LOWER': 'mikel'}, {'LENGTH': 5}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Pedro Jose'},
#    {'LOWER': 'pedro jose'},
#    {'LENGTH': 10}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Omar'}, {'LOWER': 'omar'}, {'LENGTH': 4}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Sergi'}, {'LOWER': 'sergi'}, {'LENGTH': 5}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Jose Vicente'},
#    {'LOWER': 'jose vicente'},
#    {'LENGTH': 12}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Christian'}, {'LOWER': 'christian'}, {'LENGTH': 9}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Pol'}, {'LOWER': 'pol'}, {'LENGTH': 3}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Moises'}, {'LOWER': 'moises'}, {'LENGTH': 6}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Adam'}, {'LOWER': 'adam'}, {'LENGTH': 4}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Valentin'}, {'LOWER': 'valentin'}, {'LENGTH': 8}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Jon'}, {'LOWER': 'jon'}, {'LENGTH': 3}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Gerard'}, {'LOWER': 'gerard'}, {'LENGTH': 6}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Iñigo'}, {'LOWER': 'iñigo'}, {'LENGTH': 5}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Juan Ramon'},
#    {'LOWER': 'juan ramon'},
#    {'LENGTH': 10}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Oliver'}, {'LOWER': 'oliver'}, {'LENGTH': 6}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Arnau'}, {'LOWER': 'arnau'}, {'LENGTH': 5}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Manuel Jesus'},
#    {'LOWER': 'manuel jesus'},
#    {'LENGTH': 12}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Juan Pedro'},
#    {'LOWER': 'juan pedro'},
#    {'LENGTH': 10}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Adolfo'}, {'LOWER': 'adolfo'}, {'LENGTH': 6}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Israel'}, {'LOWER': 'israel'}, {'LENGTH': 6}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Oriol'}, {'LOWER': 'oriol'}, {'LENGTH': 5}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Youssef'}, {'LOWER': 'youssef'}, {'LENGTH': 7}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Enzo'}, {'LOWER': 'enzo'}, {'LENGTH': 4}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Miquel'}, {'LOWER': 'miquel'}, {'LENGTH': 6}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Jonatan'}, {'LOWER': 'jonatan'}, {'LENGTH': 7}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Ernesto'}, {'LOWER': 'ernesto'}, {'LENGTH': 7}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Antonio Manuel'},
#    {'LOWER': 'antonio manuel'},
#    {'LENGTH': 14}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Eloy'}, {'LOWER': 'eloy'}, {'LENGTH': 4}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Isidro'}, {'LOWER': 'isidro'}, {'LENGTH': 6}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Gerardo'}, {'LOWER': 'gerardo'}, {'LENGTH': 7}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Luis Alberto'},
#    {'LOWER': 'luis alberto'},
#    {'LENGTH': 12}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Bernardo'}, {'LOWER': 'bernardo'}, {'LENGTH': 8}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Saul'}, {'LOWER': 'saul'}, {'LENGTH': 4}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Jose Alberto'},
#    {'LOWER': 'jose alberto'},
#    {'LENGTH': 12}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Federico'}, {'LOWER': 'federico'}, {'LENGTH': 8}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Benito'}, {'LOWER': 'benito'}, {'LENGTH': 6}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Alonso'}, {'LOWER': 'alonso'}, {'LENGTH': 6}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Jesus Manuel'},
#    {'LOWER': 'jesus manuel'},
#    {'LENGTH': 12}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Matias'}, {'LOWER': 'matias'}, {'LENGTH': 6}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Adria'}, {'LOWER': 'adria'}, {'LENGTH': 5}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Juan Pablo'},
#    {'LOWER': 'juan pablo'},
#    {'LENGTH': 10}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Erik'}, {'LOWER': 'erik'}, {'LENGTH': 4}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Carmelo'}, {'LOWER': 'carmelo'}, {'LENGTH': 7}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Francesc'}, {'LOWER': 'francesc'}, {'LENGTH': 8}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Marti'}, {'LOWER': 'marti'}, {'LENGTH': 5}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Kevin'}, {'LOWER': 'kevin'}, {'LENGTH': 5}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Roger'}, {'LOWER': 'roger'}, {'LENGTH': 5}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Juan Jesus'},
#    {'LOWER': 'juan jesus'},
#    {'LENGTH': 10}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Alexander'}, {'LOWER': 'alexander'}, {'LENGTH': 9}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Elias'}, {'LOWER': 'elias'}, {'LENGTH': 5}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Ander'}, {'LOWER': 'ander'}, {'LENGTH': 5}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Carlos Alberto'},
#    {'LOWER': 'carlos alberto'},
#    {'LENGTH': 14}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Iñaki'}, {'LOWER': 'iñaki'}, {'LENGTH': 5}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Pascual'}, {'LOWER': 'pascual'}, {'LENGTH': 7}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Guillem'}, {'LOWER': 'guillem'}, {'LENGTH': 7}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Julen'}, {'LOWER': 'julen'}, {'LENGTH': 5}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Marco Antonio'},
#    {'LOWER': 'marco antonio'},
#    {'LENGTH': 13}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Benjamin'}, {'LOWER': 'benjamin'}, {'LENGTH': 8}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Carles'}, {'LOWER': 'carles'}, {'LENGTH': 6}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Josep Maria'},
#    {'LOWER': 'josep maria'},
#    {'LENGTH': 11}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Pedro Antonio'},
#    {'LOWER': 'pedro antonio'},
#    {'LENGTH': 13}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Abraham'}, {'LOWER': 'abraham'}, {'LENGTH': 7}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Jose Enrique'},
#    {'LOWER': 'jose enrique'},
#    {'LENGTH': 12}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Aleix'}, {'LOWER': 'aleix'}, {'LENGTH': 5}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Bartolome'}, {'LOWER': 'bartolome'}, {'LENGTH': 9}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Pere'}, {'LOWER': 'pere'}, {'LENGTH': 4}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Said'}, {'LOWER': 'said'}, {'LENGTH': 4}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Lluis'}, {'LOWER': 'lluis'}, {'LENGTH': 5}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Juan Ignacio'},
#    {'LOWER': 'juan ignacio'},
#    {'LENGTH': 12}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Antoni'}, {'LOWER': 'antoni'}, {'LENGTH': 6}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Angel Luis'},
#    {'LOWER': 'angel luis'},
#    {'LENGTH': 10}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Fermin'}, {'LOWER': 'fermin'}, {'LENGTH': 6}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Francisco Jesus'},
#    {'LOWER': 'francisco jesus'},
#    {'LENGTH': 15}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Xabier'}, {'LOWER': 'xabier'}, {'LENGTH': 6}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Marcelino'}, {'LOWER': 'marcelino'}, {'LENGTH': 9}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Jan'}, {'LOWER': 'jan'}, {'LENGTH': 3}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Leonardo'}, {'LOWER': 'leonardo'}, {'LENGTH': 8}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Luis Fernando'},
#    {'LOWER': 'luis fernando'},
#    {'LENGTH': 13}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Luca'}, {'LOWER': 'luca'}, {'LENGTH': 4}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Roman'}, {'LOWER': 'roman'}, {'LENGTH': 5}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Gorka'}, {'LOWER': 'gorka'}, {'LENGTH': 5}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Rachid'}, {'LOWER': 'rachid'}, {'LENGTH': 6}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Ferran'}, {'LOWER': 'ferran'}, {'LENGTH': 6}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Ian'}, {'LOWER': 'ian'}, {'LENGTH': 3}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Gustavo'}, {'LOWER': 'gustavo'}, {'LENGTH': 7}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Yeray'}, {'LOWER': 'yeray'}, {'LENGTH': 5}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Ali'}, {'LOWER': 'ali'}, {'LENGTH': 3}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Thiago'}, {'LOWER': 'thiago'}, {'LENGTH': 6}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Aurelio'}, {'LOWER': 'aurelio'}, {'LENGTH': 7}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Jeronimo'}, {'LOWER': 'jeronimo'}, {'LENGTH': 8}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Luis Manuel'},
#    {'LOWER': 'luis manuel'},
#    {'LENGTH': 11}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Gael'}, {'LOWER': 'gael'}, {'LENGTH': 4}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Manuel Angel'},
#    {'LOWER': 'manuel angel'},
#    {'LENGTH': 12}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Carlos Javier'},
#    {'LOWER': 'carlos javier'},
#    {'LENGTH': 13}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Damian'}, {'LOWER': 'damian'}, {'LENGTH': 6}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Jose Juan'}, {'LOWER': 'jose juan'}, {'LENGTH': 9}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Jose David'},
#    {'LOWER': 'jose david'},
#    {'LENGTH': 10}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Dylan'}, {'LOWER': 'dylan'}, {'LENGTH': 5}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Jacinto'}, {'LOWER': 'jacinto'}, {'LENGTH': 7}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Pedro Luis'},
#    {'LOWER': 'pedro luis'},
#    {'LENGTH': 10}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Biel'}, {'LOWER': 'biel'}, {'LENGTH': 4}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Nil'}, {'LOWER': 'nil'}, {'LENGTH': 3}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Enric'}, {'LOWER': 'enric'}, {'LENGTH': 5}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Julio Cesar'},
#    {'LOWER': 'julio cesar'},
#    {'LENGTH': 11}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Jairo'}, {'LOWER': 'jairo'}, {'LENGTH': 5}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Eusebio'}, {'LOWER': 'eusebio'}, {'LENGTH': 7}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Eneko'}, {'LOWER': 'eneko'}, {'LENGTH': 5}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Armando'}, {'LOWER': 'armando'}, {'LENGTH': 7}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Eduard'}, {'LOWER': 'eduard'}, {'LENGTH': 6}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Mustapha'}, {'LOWER': 'mustapha'}, {'LENGTH': 8}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Juan Bautista'},
#    {'LOWER': 'juan bautista'},
#    {'LENGTH': 13}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Victoriano'},
#    {'LOWER': 'victoriano'},
#    {'LENGTH': 10}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Jose Joaquin'},
#    {'LOWER': 'jose joaquin'},
#    {'LENGTH': 12}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Edgar'}, {'LOWER': 'edgar'}, {'LENGTH': 5}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Isidoro'}, {'LOWER': 'isidoro'}, {'LENGTH': 7}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Blas'}, {'LOWER': 'blas'}, {'LENGTH': 4}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Gines'}, {'LOWER': 'gines'}, {'LENGTH': 5}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Juan Maria'},
#    {'LOWER': 'juan maria'},
#    {'LENGTH': 10}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Francisco Antonio'},
#    {'LOWER': 'francisco antonio'},
#    {'LENGTH': 17}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Simon'}, {'LOWER': 'simon'}, {'LENGTH': 5}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Santos'}, {'LOWER': 'santos'}, {'LENGTH': 6}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Emilio Jose'},
#    {'LOWER': 'emilio jose'},
#    {'LENGTH': 11}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Jose Andres'},
#    {'LOWER': 'jose andres'},
#    {'LENGTH': 11}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Teodoro'}, {'LOWER': 'teodoro'}, {'LENGTH': 7}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Luis Angel'},
#    {'LOWER': 'luis angel'},
#    {'LENGTH': 10}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Dionisio'}, {'LOWER': 'dionisio'}, {'LENGTH': 8}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Jacobo'}, {'LOWER': 'jacobo'}, {'LENGTH': 6}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Luis Antonio'},
#    {'LOWER': 'luis antonio'},
#    {'LENGTH': 12}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Candido'}, {'LOWER': 'candido'}, {'LENGTH': 7}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Justo'}, {'LOWER': 'justo'}, {'LENGTH': 5}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Igor'}, {'LOWER': 'igor'}, {'LENGTH': 4}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Maximo'}, {'LOWER': 'maximo'}, {'LENGTH': 6}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Alexis'}, {'LOWER': 'alexis'}, {'LENGTH': 6}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Hamza'}, {'LOWER': 'hamza'}, {'LENGTH': 5}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Jesus Angel'},
#    {'LOWER': 'jesus angel'},
#    {'LENGTH': 11}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Ayoub'}, {'LOWER': 'ayoub'}, {'LENGTH': 5}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Emiliano'}, {'LOWER': 'emiliano'}, {'LENGTH': 8}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Yago'}, {'LOWER': 'yago'}, {'LENGTH': 4}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Florencio'}, {'LOWER': 'florencio'}, {'LENGTH': 9}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Hassan'}, {'LOWER': 'hassan'}, {'LENGTH': 6}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Rayan'}, {'LOWER': 'rayan'}, {'LENGTH': 5}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Muhammad'}, {'LOWER': 'muhammad'}, {'LENGTH': 8}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Juan Diego'},
#    {'LOWER': 'juan diego'},
#    {'LENGTH': 10}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Jorge Luis'},
#    {'LOWER': 'jorge luis'},
#    {'LENGTH': 10}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Ezequiel'}, {'LOWER': 'ezequiel'}, {'LENGTH': 8}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Mauro'}, {'LOWER': 'mauro'}, {'LENGTH': 5}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Alexandre'}, {'LOWER': 'alexandre'}, {'LENGTH': 9}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Luis Maria'},
#    {'LOWER': 'luis maria'},
#    {'LENGTH': 10}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Ibai'}, {'LOWER': 'ibai'}, {'LENGTH': 4}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Serafin'}, {'LOWER': 'serafin'}, {'LENGTH': 7}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Jose Daniel'},
#    {'LOWER': 'jose daniel'},
#    {'LENGTH': 11}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Francisco Miguel'},
#    {'LOWER': 'francisco miguel'},
#    {'LENGTH': 16}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Manuel Antonio'},
#    {'LOWER': 'manuel antonio'},
#    {'LENGTH': 14}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Andreu'}, {'LOWER': 'andreu'}, {'LENGTH': 6}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Iago'}, {'LOWER': 'iago'}, {'LENGTH': 4}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Ramiro'}, {'LOWER': 'ramiro'}, {'LENGTH': 6}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Claudio'}, {'LOWER': 'claudio'}, {'LENGTH': 7}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Pedro Manuel'},
#    {'LOWER': 'pedro manuel'},
#    {'LENGTH': 12}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Faustino'}, {'LOWER': 'faustino'}, {'LENGTH': 8}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Fidel'}, {'LOWER': 'fidel'}, {'LENGTH': 5}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Aimar'}, {'LOWER': 'aimar'}, {'LENGTH': 5}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Aritz'}, {'LOWER': 'aritz'}, {'LENGTH': 5}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Alan'}, {'LOWER': 'alan'}, {'LENGTH': 4}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Jose Fernando'},
#    {'LOWER': 'jose fernando'},
#    {'LENGTH': 13}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Bilal'}, {'LOWER': 'bilal'}, {'LENGTH': 5}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Khalid'}, {'LOWER': 'khalid'}, {'LENGTH': 6}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Amador'}, {'LOWER': 'amador'}, {'LENGTH': 6}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Carlos Manuel'},
#    {'LOWER': 'carlos manuel'},
#    {'LENGTH': 13}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Juan Andres'},
#    {'LOWER': 'juan andres'},
#    {'LENGTH': 11}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Ion'}, {'LOWER': 'ion'}, {'LENGTH': 3}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Fabio'}, {'LOWER': 'fabio'}, {'LENGTH': 5}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Liam'}, {'LOWER': 'liam'}, {'LENGTH': 4}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Josue'}, {'LOWER': 'josue'}, {'LENGTH': 5}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Juan Dios'}, {'LOWER': 'juan dios'}, {'LENGTH': 9}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Luciano'}, {'LOWER': 'luciano'}, {'LENGTH': 7}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Rogelio'}, {'LOWER': 'rogelio'}, {'LENGTH': 7}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Cayetano'}, {'LOWER': 'cayetano'}, {'LENGTH': 8}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Antonio Javier'},
#    {'LOWER': 'antonio javier'},
#    {'LENGTH': 14}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Manuel Jose'},
#    {'LOWER': 'manuel jose'},
#    {'LENGTH': 11}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Juan Vicente'},
#    {'LOWER': 'juan vicente'},
#    {'LENGTH': 12}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Luis Carlos'},
#    {'LOWER': 'luis carlos'},
#    {'LENGTH': 11}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Leandro'}, {'LOWER': 'leandro'}, {'LENGTH': 7}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Joaquim'}, {'LOWER': 'joaquim'}, {'LENGTH': 7}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Abdellah'}, {'LOWER': 'abdellah'}, {'LENGTH': 8}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Antonio Miguel'},
#    {'LOWER': 'antonio miguel'},
#    {'LENGTH': 14}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Luis Javier'},
#    {'LOWER': 'luis javier'},
#    {'LENGTH': 11}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Fabian'}, {'LOWER': 'fabian'}, {'LENGTH': 6}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Hicham'}, {'LOWER': 'hicham'}, {'LENGTH': 6}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Markel'}, {'LOWER': 'markel'}, {'LENGTH': 6}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Antonio Luis'},
#    {'LOWER': 'antonio luis'},
#    {'LENGTH': 12}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Ildefonso'}, {'LOWER': 'ildefonso'}, {'LENGTH': 9}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Pedro Jesus'},
#    {'LOWER': 'pedro jesus'},
#    {'LENGTH': 11}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Manel'}, {'LOWER': 'manel'}, {'LENGTH': 5}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Nestor'}, {'LOWER': 'nestor'}, {'LENGTH': 6}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Yassine'}, {'LOWER': 'yassine'}, {'LENGTH': 7}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Robert'}, {'LOWER': 'robert'}, {'LENGTH': 6}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Ibrahim'}, {'LOWER': 'ibrahim'}, {'LENGTH': 7}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Modesto'}, {'LOWER': 'modesto'}, {'LENGTH': 7}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Oier'}, {'LOWER': 'oier'}, {'LENGTH': 4}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Pedro Maria'},
#    {'LOWER': 'pedro maria'},
#    {'LENGTH': 11}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Juan David'},
#    {'LOWER': 'juan david'},
#    {'LENGTH': 10}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Anas'}, {'LOWER': 'anas'}, {'LENGTH': 4}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Francesc Xavier'},
#    {'LOWER': 'francesc xavier'},
#    {'LENGTH': 15}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Angel Manuel'},
#    {'LOWER': 'angel manuel'},
#    {'LENGTH': 12}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Juan Angel'},
#    {'LOWER': 'juan angel'},
#    {'LENGTH': 10}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Brais'}, {'LOWER': 'brais'}, {'LENGTH': 5}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Florentino'},
#    {'LOWER': 'florentino'},
#    {'LENGTH': 10}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Marcelo'}, {'LOWER': 'marcelo'}, {'LENGTH': 7}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Brahim'}, {'LOWER': 'brahim'}, {'LENGTH': 6}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Imanol'}, {'LOWER': 'imanol'}, {'LENGTH': 6}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Noah'}, {'LOWER': 'noah'}, {'LENGTH': 4}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Luis Enrique'},
#    {'LOWER': 'luis enrique'},
#    {'LENGTH': 12}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Constantino'},
#    {'LOWER': 'constantino'},
#    {'LENGTH': 11}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Noel'}, {'LOWER': 'noel'}, {'LENGTH': 4}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Paulino'}, {'LOWER': 'paulino'}, {'LENGTH': 7}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Eladio'}, {'LOWER': 'eladio'}, {'LENGTH': 6}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Abdelkader'},
#    {'LOWER': 'abdelkader'},
#    {'LENGTH': 10}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Anton'}, {'LOWER': 'anton'}, {'LENGTH': 5}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Axel'}, {'LOWER': 'axel'}, {'LENGTH': 4}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Amir'}, {'LOWER': 'amir'}, {'LENGTH': 4}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Avelino'}, {'LOWER': 'avelino'}, {'LENGTH': 7}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Ricard'}, {'LOWER': 'ricard'}, {'LENGTH': 6}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Celestino'}, {'LOWER': 'celestino'}, {'LENGTH': 9}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Bernat'}, {'LOWER': 'bernat'}, {'LENGTH': 6}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Andoni'}, {'LOWER': 'andoni'}, {'LENGTH': 6}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Fernando Jose'},
#    {'LOWER': 'fernando jose'},
#    {'LENGTH': 13}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Juan Alberto'},
#    {'LOWER': 'juan alberto'},
#    {'LENGTH': 12}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Didac'}, {'LOWER': 'didac'}, {'LENGTH': 5}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Vasile'}, {'LOWER': 'vasile'}, {'LENGTH': 6}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Roberto Carlos'},
#    {'LOWER': 'roberto carlos'},
#    {'LENGTH': 14}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Gheorghe'}, {'LOWER': 'gheorghe'}, {'LENGTH': 8}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Josu'}, {'LOWER': 'josu'}, {'LENGTH': 4}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Gaspar'}, {'LOWER': 'gaspar'}, {'LENGTH': 6}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Jesus Antonio'},
#    {'LOWER': 'jesus antonio'},
#    {'LENGTH': 13}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Max'}, {'LOWER': 'max'}, {'LENGTH': 3}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Saturnino'}, {'LOWER': 'saturnino'}, {'LENGTH': 9}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Marcel'}, {'LOWER': 'marcel'}, {'LENGTH': 6}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Abderrahim'},
#    {'LOWER': 'abderrahim'},
#    {'LENGTH': 10}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Rufino'}, {'LOWER': 'rufino'}, {'LENGTH': 6}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Abdelaziz'}, {'LOWER': 'abdelaziz'}, {'LENGTH': 9}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Karim'}, {'LOWER': 'karim'}, {'LENGTH': 5}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Joseba'}, {'LOWER': 'joseba'}, {'LENGTH': 6}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Angel Maria'},
#    {'LOWER': 'angel maria'},
#    {'LENGTH': 11}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Adan'}, {'LOWER': 'adan'}, {'LENGTH': 4}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Clemente'}, {'LOWER': 'clemente'}, {'LENGTH': 8}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Manuel Alejandro'},
#    {'LOWER': 'manuel alejandro'},
#    {'LENGTH': 16}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Michael'}, {'LOWER': 'michael'}, {'LENGTH': 7}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Ismail'}, {'LOWER': 'ismail'}, {'LENGTH': 6}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Mauricio'}, {'LOWER': 'mauricio'}, {'LENGTH': 8}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Pedro Pablo'},
#    {'LOWER': 'pedro pablo'},
#    {'LENGTH': 11}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Basilio'}, {'LOWER': 'basilio'}, {'LENGTH': 7}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Hamid'}, {'LOWER': 'hamid'}, {'LENGTH': 5}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Zakaria'}, {'LOWER': 'zakaria'}, {'LENGTH': 7}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Raimundo'}, {'LOWER': 'raimundo'}, {'LENGTH': 8}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Ioan'}, {'LOWER': 'ioan'}, {'LENGTH': 4}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Antonio Francisco'},
#    {'LOWER': 'antonio francisco'},
#    {'LENGTH': 17}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Mamadou'}, {'LOWER': 'mamadou'}, {'LENGTH': 7}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Alain'}, {'LOWER': 'alain'}, {'LENGTH': 5}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Pelayo'}, {'LOWER': 'pelayo'}, {'LENGTH': 6}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Feliciano'}, {'LOWER': 'feliciano'}, {'LENGTH': 9}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Brian'}, {'LOWER': 'brian'}, {'LENGTH': 5}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Hilario'}, {'LOWER': 'hilario'}, {'LENGTH': 7}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Francisco Luis'},
#    {'LOWER': 'francisco luis'},
#    {'LENGTH': 14}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Teo'}, {'LOWER': 'teo'}, {'LENGTH': 3}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Marcial'}, {'LOWER': 'marcial'}, {'LENGTH': 7}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Carlos Jose'},
#    {'LOWER': 'carlos jose'},
#    {'LENGTH': 11}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Patricio'}, {'LOWER': 'patricio'}, {'LENGTH': 8}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Evaristo'}, {'LOWER': 'evaristo'}, {'LENGTH': 8}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Pedro Javier'},
#    {'LOWER': 'pedro javier'},
#    {'LENGTH': 12}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Denis'}, {'LOWER': 'denis'}, {'LENGTH': 5}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Camilo'}, {'LOWER': 'camilo'}, {'LENGTH': 6}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Lluc'}, {'LOWER': 'lluc'}, {'LENGTH': 4}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Eliseo'}, {'LOWER': 'eliseo'}, {'LENGTH': 6}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Moussa'}, {'LOWER': 'moussa'}, {'LENGTH': 6}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Roque'}, {'LOWER': 'roque'}, {'LENGTH': 5}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Oleksandr'}, {'LOWER': 'oleksandr'}, {'LENGTH': 9}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Laureano'}, {'LOWER': 'laureano'}, {'LENGTH': 8}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Jamal'}, {'LOWER': 'jamal'}, {'LENGTH': 5}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Jose Gabriel'},
#    {'LOWER': 'jose gabriel'},
#    {'LENGTH': 12}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Paul'}, {'LOWER': 'paul'}, {'LENGTH': 4}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Narciso'}, {'LOWER': 'narciso'}, {'LENGTH': 7}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Pedro Miguel'},
#    {'LOWER': 'pedro miguel'},
#    {'LENGTH': 12}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Eloi'}, {'LOWER': 'eloi'}, {'LENGTH': 4}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Francisco Borja'},
#    {'LOWER': 'francisco borja'},
#    {'LENGTH': 15}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Constantin'},
#    {'LOWER': 'constantin'},
#    {'LENGTH': 10}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Jose Alejandro'},
#    {'LOWER': 'jose alejandro'},
#    {'LENGTH': 14}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Leopoldo'}, {'LOWER': 'leopoldo'}, {'LENGTH': 8}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Cecilio'}, {'LOWER': 'cecilio'}, {'LENGTH': 7}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Bernardino'},
#    {'LOWER': 'bernardino'},
#    {'LENGTH': 10}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Andres Felipe'},
#    {'LOWER': 'andres felipe'},
#    {'LENGTH': 13}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Benigno'}, {'LOWER': 'benigno'}, {'LENGTH': 7}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Aday'}, {'LOWER': 'aday'}, {'LENGTH': 4}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Jose Rafael'},
#    {'LOWER': 'jose rafael'},
#    {'LENGTH': 11}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Francisco Asis'},
#    {'LOWER': 'francisco asis'},
#    {'LENGTH': 14}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Aziz'}, {'LOWER': 'aziz'}, {'LENGTH': 4}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Alessandro'},
#    {'LOWER': 'alessandro'},
#    {'LENGTH': 10}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Jesus Miguel'},
#    {'LOWER': 'jesus miguel'},
#    {'LENGTH': 12}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Jose Felix'},
#    {'LOWER': 'jose felix'},
#    {'LENGTH': 10}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Ayman'}, {'LOWER': 'ayman'}, {'LENGTH': 5}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Rodolfo'}, {'LOWER': 'rodolfo'}, {'LENGTH': 7}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Segundo'}, {'LOWER': 'segundo'}, {'LENGTH': 7}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Octavio'}, {'LOWER': 'octavio'}, {'LENGTH': 7}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Driss'}, {'LOWER': 'driss'}, {'LENGTH': 5}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Luis Francisco'},
#    {'LOWER': 'luis francisco'},
#    {'LENGTH': 14}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Gustavo Adolfo'},
#    {'LOWER': 'gustavo adolfo'},
#    {'LENGTH': 14}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Jose Pedro'},
#    {'LOWER': 'jose pedro'},
#    {'LENGTH': 10}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Beñat'}, {'LOWER': 'beñat'}, {'LENGTH': 5}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Nabil'}, {'LOWER': 'nabil'}, {'LENGTH': 5}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Samir'}, {'LOWER': 'samir'}, {'LENGTH': 5}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Marian'}, {'LOWER': 'marian'}, {'LENGTH': 6}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Imran'}, {'LOWER': 'imran'}, {'LENGTH': 5}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Alberto Jose'},
#    {'LOWER': 'alberto jose'},
#    {'LENGTH': 12}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Abdeslam'}, {'LOWER': 'abdeslam'}, {'LENGTH': 8}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Valeriano'}, {'LOWER': 'valeriano'}, {'LENGTH': 9}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Younes'}, {'LOWER': 'younes'}, {'LENGTH': 6}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Manuel Francisco'},
#    {'LOWER': 'manuel francisco'},
#    {'LENGTH': 16}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Carlos Enrique'},
#    {'LOWER': 'carlos enrique'},
#    {'LENGTH': 14}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Kilian'}, {'LOWER': 'kilian'}, {'LENGTH': 6}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Demetrio'}, {'LOWER': 'demetrio'}, {'LENGTH': 8}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Luis Eduardo'},
#    {'LOWER': 'luis eduardo'},
#    {'LENGTH': 12}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Yassin'}, {'LOWER': 'yassin'}, {'LENGTH': 6}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Cesareo'}, {'LOWER': 'cesareo'}, {'LENGTH': 7}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Adil'}, {'LOWER': 'adil'}, {'LENGTH': 4}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Carlos Andres'},
#    {'LOWER': 'carlos andres'},
#    {'LENGTH': 13}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Unax'}, {'LOWER': 'unax'}, {'LENGTH': 4}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Juan Sebastian'},
#    {'LOWER': 'juan sebastian'},
#    {'LENGTH': 14}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Noe'}, {'LOWER': 'noe'}, {'LENGTH': 3}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Ignasi'}, {'LOWER': 'ignasi'}, {'LENGTH': 6}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Lazaro'}, {'LOWER': 'lazaro'}, {'LENGTH': 6}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Pablo Jose'},
#    {'LOWER': 'pablo jose'},
#    {'LENGTH': 10}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Bernabe'}, {'LOWER': 'bernabe'}, {'LENGTH': 7}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Juan Enrique'},
#    {'LOWER': 'juan enrique'},
#    {'LENGTH': 12}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Jesus Javier'},
#    {'LOWER': 'jesus javier'},
#    {'LENGTH': 12}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Juan Gabriel'},
#    {'LOWER': 'juan gabriel'},
#    {'LENGTH': 12}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Orlando'}, {'LOWER': 'orlando'}, {'LENGTH': 7}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Anibal'}, {'LOWER': 'anibal'}, {'LENGTH': 6}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Victor Jose'},
#    {'LOWER': 'victor jose'},
#    {'LENGTH': 11}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Jose Domingo'},
#    {'LOWER': 'jose domingo'},
#    {'LENGTH': 12}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Vicent'}, {'LOWER': 'vicent'}, {'LENGTH': 6}]},
#  {'label': 'FIRST_NAME',
# ...
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Dimas'}, {'LOWER': 'dimas'}, {'LENGTH': 5}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'David Alejandro'},
#    {'LOWER': 'david alejandro'},
#    {'LENGTH': 15}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Maxim'}, {'LOWER': 'maxim'}, {'LENGTH': 5}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Andriy'}, {'LOWER': 'andriy'}, {'LENGTH': 6}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Enrique Manuel'},
#    {'LOWER': 'enrique manuel'},
#    {'LENGTH': 14}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Albino'}, {'LOWER': 'albino'}, {'LENGTH': 6}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Pavel'}, {'LOWER': 'pavel'}, {'LENGTH': 5}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Frank'}, {'LOWER': 'frank'}, {'LENGTH': 5}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Celedonio'}, {'LOWER': 'celedonio'}, {'LENGTH': 9}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Angel Javier'},
#    {'LOWER': 'angel javier'},
#    {'LENGTH': 12}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Jesus Jose'},
#    {'LOWER': 'jesus jose'},
#    {'LENGTH': 10}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Antonio Vicente'},
#    {'LOWER': 'antonio vicente'},
#    {'LENGTH': 15}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Manuel Vicente'},
#    {'LOWER': 'manuel vicente'},
#    {'LENGTH': 14}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Issam'}, {'LOWER': 'issam'}, {'LENGTH': 5}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Juan Domingo'},
#    {'LOWER': 'juan domingo'},
#    {'LENGTH': 12}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Servando'}, {'LOWER': 'servando'}, {'LENGTH': 8}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Florian'}, {'LOWER': 'florian'}, {'LENGTH': 7}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Eustaquio'}, {'LOWER': 'eustaquio'}, {'LENGTH': 9}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Gil'}, {'LOWER': 'gil'}, {'LENGTH': 3}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Francisco Rafael'},
#    {'LOWER': 'francisco rafael'},
#    {'LENGTH': 16}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Francisco Daniel'},
#    {'LOWER': 'francisco daniel'},
#    {'LENGTH': 16}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Walter'}, {'LOWER': 'walter'}, {'LENGTH': 6}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Arcadio'}, {'LOWER': 'arcadio'}, {'LENGTH': 7}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Badr'}, {'LOWER': 'badr'}, {'LENGTH': 4}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Jorge Andres'},
#    {'LOWER': 'jorge andres'},
#    {'LENGTH': 12}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Jose Santiago'},
#    {'LOWER': 'jose santiago'},
#    {'LENGTH': 13}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Rolando'}, {'LOWER': 'rolando'}, {'LENGTH': 7}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Daniel Jose'},
#    {'LOWER': 'daniel jose'},
#    {'LENGTH': 11}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Luis Ramon'},
#    {'LOWER': 'luis ramon'},
#    {'LENGTH': 10}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Michel'}, {'LOWER': 'michel'}, {'LENGTH': 6}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Jesus Ignacio'},
#    {'LOWER': 'jesus ignacio'},
#    {'LENGTH': 13}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Manuel Fernando'},
#    {'LOWER': 'manuel fernando'},
#    {'LENGTH': 15}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Jose Ivan'}, {'LOWER': 'jose ivan'}, {'LENGTH': 9}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Andres Jesus'},
#    {'LOWER': 'andres jesus'},
#    {'LENGTH': 12}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Abdelhadi'}, {'LOWER': 'abdelhadi'}, {'LENGTH': 9}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Koldo'}, {'LOWER': 'koldo'}, {'LENGTH': 5}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Angelo'}, {'LOWER': 'angelo'}, {'LENGTH': 6}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Cheikh'}, {'LOWER': 'cheikh'}, {'LENGTH': 6}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Amado'}, {'LOWER': 'amado'}, {'LENGTH': 5}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Angel Gabriel'},
#    {'LOWER': 'angel gabriel'},
#    {'LENGTH': 13}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Marçal'}, {'LOWER': 'marçal'}, {'LENGTH': 6}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Oscar Javier'},
#    {'LOWER': 'oscar javier'},
#    {'LENGTH': 12}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Manuel Alberto'},
#    {'LOWER': 'manuel alberto'},
#    {'LENGTH': 14}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Olegario'}, {'LOWER': 'olegario'}, {'LENGTH': 8}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Miquel Angel'},
#    {'LOWER': 'miquel angel'},
#    {'LENGTH': 12}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Paulo'}, {'LOWER': 'paulo'}, {'LENGTH': 5}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Antonio Rafael'},
#    {'LOWER': 'antonio rafael'},
#    {'LENGTH': 14}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'David Jose'},
#    {'LOWER': 'david jose'},
#    {'LENGTH': 10}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Pablo Javier'},
#    {'LOWER': 'pablo javier'},
#    {'LENGTH': 12}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Ihor'}, {'LOWER': 'ihor'}, {'LENGTH': 4}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Jesus Carlos'},
#    {'LOWER': 'jesus carlos'},
#    {'LENGTH': 12}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Argimiro'}, {'LOWER': 'argimiro'}, {'LENGTH': 8}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Soufian'}, {'LOWER': 'soufian'}, {'LENGTH': 7}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Nicasio'}, {'LOWER': 'nicasio'}, {'LENGTH': 7}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Mehdi'}, {'LOWER': 'mehdi'}, {'LENGTH': 5}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Francisco Juan'},
#    {'LOWER': 'francisco juan'},
#    {'LENGTH': 14}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Dennis'}, {'LOWER': 'dennis'}, {'LENGTH': 6}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Zacarias'}, {'LOWER': 'zacarias'}, {'LENGTH': 8}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Dan'}, {'LOWER': 'dan'}, {'LENGTH': 3}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Alberto Manuel'},
#    {'LOWER': 'alberto manuel'},
#    {'LENGTH': 14}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Bartomeu'}, {'LOWER': 'bartomeu'}, {'LENGTH': 8}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Jordan'}, {'LOWER': 'jordan'}, {'LENGTH': 6}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'James'}, {'LOWER': 'james'}, {'LENGTH': 5}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Eiden'}, {'LOWER': 'eiden'}, {'LENGTH': 5}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Salim'}, {'LOWER': 'salim'}, {'LENGTH': 5}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Jesus Enrique'},
#    {'LOWER': 'jesus enrique'},
#    {'LENGTH': 13}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Juan Marcos'},
#    {'LOWER': 'juan marcos'},
#    {'LENGTH': 11}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Jose Guillermo'},
#    {'LOWER': 'jose guillermo'},
#    {'LENGTH': 14}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Steven'}, {'LOWER': 'steven'}, {'LENGTH': 6}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Jose Jorge'},
#    {'LOWER': 'jose jorge'},
#    {'LENGTH': 10}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Edwin'}, {'LOWER': 'edwin'}, {'LENGTH': 5}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Enrique Javier'},
#    {'LOWER': 'enrique javier'},
#    {'LENGTH': 14}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Adnan'}, {'LOWER': 'adnan'}, {'LENGTH': 5}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Peio'}, {'LOWER': 'peio'}, {'LENGTH': 4}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Jean Carlos'},
#    {'LOWER': 'jean carlos'},
#    {'LENGTH': 11}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Fernando Luis'},
#    {'LOWER': 'fernando luis'},
#    {'LENGTH': 13}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Diego Antonio'},
#    {'LOWER': 'diego antonio'},
#    {'LENGTH': 13}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Amancio'}, {'LOWER': 'amancio'}, {'LENGTH': 7}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Juan Agustin'},
#    {'LOWER': 'juan agustin'},
#    {'LENGTH': 12}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Epifanio'}, {'LOWER': 'epifanio'}, {'LENGTH': 8}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Fernando Antonio'},
#    {'LOWER': 'fernando antonio'},
#    {'LENGTH': 16}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Otman'}, {'LOWER': 'otman'}, {'LENGTH': 5}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Facundo'}, {'LOWER': 'facundo'}, {'LENGTH': 7}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Donato'}, {'LOWER': 'donato'}, {'LENGTH': 6}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Jose Eugenio'},
#    {'LOWER': 'jose eugenio'},
#    {'LENGTH': 12}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Miguel Jesus'},
#    {'LOWER': 'miguel jesus'},
#    {'LENGTH': 12}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Lukas'}, {'LOWER': 'lukas'}, {'LENGTH': 5}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Haron'}, {'LOWER': 'haron'}, {'LENGTH': 5}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Cristofer'}, {'LOWER': 'cristofer'}, {'LENGTH': 9}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Sergio Manuel'},
#    {'LOWER': 'sergio manuel'},
#    {'LENGTH': 13}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Joan Carles'},
#    {'LOWER': 'joan carles'},
#    {'LENGTH': 11}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Luis Vicente'},
#    {'LOWER': 'luis vicente'},
#    {'LENGTH': 12}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Lamine'}, {'LOWER': 'lamine'}, {'LENGTH': 6}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Jose Mario'},
#    {'LOWER': 'jose mario'},
#    {'LENGTH': 10}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Justino'}, {'LOWER': 'justino'}, {'LENGTH': 7}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Aleksandr'}, {'LOWER': 'aleksandr'}, {'LENGTH': 9}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Luken'}, {'LOWER': 'luken'}, {'LENGTH': 5}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Alfonso Carlos'},
#    {'LOWER': 'alfonso carlos'},
#    {'LENGTH': 14}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Balbino'}, {'LOWER': 'balbino'}, {'LENGTH': 7}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Cosme'}, {'LOWER': 'cosme'}, {'LENGTH': 5}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Antonino'}, {'LOWER': 'antonino'}, {'LENGTH': 8}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Javier Antonio'},
#    {'LOWER': 'javier antonio'},
#    {'LENGTH': 14}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Kepa'}, {'LOWER': 'kepa'}, {'LENGTH': 4}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Carlos Fernando'},
#    {'LOWER': 'carlos fernando'},
#    {'LENGTH': 15}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Abilio'}, {'LOWER': 'abilio'}, {'LENGTH': 6}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Guillermo Jose'},
#    {'LOWER': 'guillermo jose'},
#    {'LENGTH': 14}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Rafel'}, {'LOWER': 'rafel'}, {'LENGTH': 5}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Redouane'}, {'LOWER': 'redouane'}, {'LENGTH': 8}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Ciro'}, {'LOWER': 'ciro'}, {'LENGTH': 4}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Francisco Angel'},
#    {'LOWER': 'francisco angel'},
#    {'LENGTH': 15}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Adonay'}, {'LOWER': 'adonay'}, {'LENGTH': 6}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Manuel David'},
#    {'LOWER': 'manuel david'},
#    {'LENGTH': 12}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Costel'}, {'LOWER': 'costel'}, {'LENGTH': 6}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Henry'}, {'LOWER': 'henry'}, {'LENGTH': 5}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Jhon Jairo'},
#    {'LOWER': 'jhon jairo'},
#    {'LENGTH': 10}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Buenaventura'},
#    {'LOWER': 'buenaventura'},
#    {'LENGTH': 12}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Remigio'}, {'LOWER': 'remigio'}, {'LENGTH': 7}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Manuel Carlos'},
#    {'LOWER': 'manuel carlos'},
#    {'LENGTH': 13}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Oumar'}, {'LOWER': 'oumar'}, {'LENGTH': 5}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Alberto Jesus'},
#    {'LOWER': 'alberto jesus'},
#    {'LENGTH': 13}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Abdelhakim'},
#    {'LOWER': 'abdelhakim'},
#    {'LENGTH': 10}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Miguel Alejandro'},
#    {'LOWER': 'miguel alejandro'},
#    {'LENGTH': 16}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Musa'}, {'LOWER': 'musa'}, {'LENGTH': 4}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Petru'}, {'LOWER': 'petru'}, {'LENGTH': 5}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Emil'}, {'LOWER': 'emil'}, {'LENGTH': 4}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Roberto Jose'},
#    {'LOWER': 'roberto jose'},
#    {'LENGTH': 12}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Ramon Jose'},
#    {'LOWER': 'ramon jose'},
#    {'LENGTH': 10}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Victorio'}, {'LOWER': 'victorio'}, {'LENGTH': 8}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Amar'}, {'LOWER': 'amar'}, {'LENGTH': 4}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Davide'}, {'LOWER': 'davide'}, {'LENGTH': 6}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Joan Josep'},
#    {'LOWER': 'joan josep'},
#    {'LENGTH': 10}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Franco'}, {'LOWER': 'franco'}, {'LENGTH': 6}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Miguel Maria'},
#    {'LOWER': 'miguel maria'},
#    {'LENGTH': 12}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'El Mostafa'},
#    {'LOWER': 'el mostafa'},
#    {'LENGTH': 10}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Iulian'}, {'LOWER': 'iulian'}, {'LENGTH': 6}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Jose Diego'},
#    {'LOWER': 'jose diego'},
#    {'LENGTH': 10}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Juan Emilio'},
#    {'LOWER': 'juan emilio'},
#    {'LENGTH': 11}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Julian Andres'},
#    {'LOWER': 'julian andres'},
#    {'LENGTH': 13}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Jesus Luis'},
#    {'LOWER': 'jesus luis'},
#    {'LENGTH': 10}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Anwar'}, {'LOWER': 'anwar'}, {'LENGTH': 5}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'David Jesus'},
#    {'LOWER': 'david jesus'},
#    {'LENGTH': 11}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Sergio Jose'},
#    {'LOWER': 'sergio jose'},
#    {'LENGTH': 11}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Jose Damian'},
#    {'LOWER': 'jose damian'},
#    {'LENGTH': 11}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Iyad'}, {'LOWER': 'iyad'}, {'LENGTH': 4}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Marin'}, {'LOWER': 'marin'}, {'LENGTH': 5}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Jose Felipe'},
#    {'LOWER': 'jose felipe'},
#    {'LENGTH': 11}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Cristian David'},
#    {'LOWER': 'cristian david'},
#    {'LENGTH': 14}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Nikolay'}, {'LOWER': 'nikolay'}, {'LENGTH': 7}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Rayco'}, {'LOWER': 'rayco'}, {'LENGTH': 5}]},
#  {'label': 'FIRST_NAME',
#   'pattern': [{'ORTH': 'Alberto Javier'},
#    {'LOWER': 'alberto javier'},
#    {'LENGTH': 14}]},
#  ...]

# %%
text = document_text.split()

# %%
i = 0

# %%
modified_text = []
while i < len(text):
    print(f"i: {i}")
    if i+1 < len(text):
        combined = text[i] + text[i+1]
        #print("Combined element: " + combined)
        doc = nlp(combined)
        if len(doc.ents) == 0:
            modified_text.append(text[i])
            i += 1
        else:
            for ent in doc.ents:
                print(doc.ents)
                print(ent.label_)
                if ent.label_ == "PER":
                    print("Person!")
                    modified_text.append(combined)
                    i += 2
                    break
                else:
                    print("Not a person.")
                    modified_text.append(text[i])
                    i += 1
# Out:
# i: 0
# i: 1
# i: 2
# i: 3
# i: 4
# i: 5
# (laLoma,)
# LOC
# Not a person.
# i: 6
# i: 7
# i: 8
# i: 9
# i: 10
# (paraChiscote,)
# MISC
# Not a person.
# i: 11
# (Chiscote,)
# MISC
# Not a person.
# i: 12
# (laque,)
# PER
# Person!
# i: 14
# (huboen,)
# MISC
# Not a person.
# i: 15
# (enel,)
# PER
# Person!
# i: 17
# (repartodel,)
# PER
# Person!
# i: 19
# (resguardode,)
# LOC
# Not a person.
# i: 20
# i: 21
# i: 22
# i: 23
# (ElCocuy,)
# LOC
# Not a person.
# i: 24
# i: 25
# i: 26
# i: 27
# (juliode,)
# PER
# Person!
# i: 29
# (1858-Eleuterio,)
# MISC
# Not a person.
# i: 30
# i: 31
# (yJulian,)
# MISC
# Not a person.
# i: 32
# (JulianPatricio,)
# LOC
# Not a person.
# i: 33
# (Patriciovenden,)
# PER
# Person!
# i: 35
# (aJoaquín,)
# MISC
# Not a person.
# i: 36
# (Joaquín1,)
# ORG
# Not a person.
# i: 37
# i: 38
# (aríaEspinel,)
# LOC
# Not a person.
# i: 39
# i: 40
# i: 41
# (derechoy,)
# PER
# Person!
# i: 43
# (acciónque,)
# LOC
# Not a person.
# i: 44
# (quea,)
# PER
# Person!
# i: 46
# (cadauno,)
# PER
# Person!
# i: 48
# (lecorresponde,)
# LOC
# Not a person.
# i: 49
# (correspondeen,)
# PER
# Person!
# i: 51
# (lastierras,)
# PER
# Person!
# i: 53
# (delAlizal,)
# MISC
# Not a person.
# i: 54
# (Alizal,)
# PER
# Person!
# i: 56
# (ravereda,)
# LOC
# Not a person.
# i: 57
# (veredado,)
# LOC
# Not a person.
# i: 58
# (do.laa,)
# MISC
# Not a person.
# i: 59
# i: 60
# (Tapiasjurisdicción,)
# MISC
# Not a person.
# i: 61
# i: 62
# i: 63
# (Chiscas,)
# LOC
# Not a person.
# i: 64
# (lasque,)
# ORG
# Not a person.
# i: 65
# i: 66
# (hubieronen,)
# PER
# Person!
# i: 68
# i: 69
# (repartodel,)
# PER
# Person!
# i: 71
# (resguardode,)
# LOC
# Not a person.
# i: 72
# (deíndíjenas,)
# LOC
# Not a person.
# i: 73
# (índíjenasde,)
# LOC
# Not a person.
# i: 74
# (dedicho,)
# LOC
# Not a person.
# i: 75
# i: 76
# i: 77
# (#,)
# MISC
# Not a person.
# i: 78
# (ElCocuy,)
# LOC
# Not a person.
# i: 79
# i: 80
# i: 81
# i: 82
# (juliode,)
# PER
# Person!
# i: 84
# i: 85
# (JuanCrisostomo,)
# MISC
# Not a person.
# i: 86
# (CrisostomoRo,)
# LOC
# Not a person.
# i: 87
# (Rodríguez,)
# PER
# Person!
# i: 89
# i: 90
# (aGavino,)
# MISC
# Not a person.
# i: 91
# (GavinoLargo,)
# LOC
# Not a person.
# i: 92
# (Largoun,)
# MISC
# Not a person.
# i: 93
# i: 94
# (pedazode,)
# LOC
# Not a person.
# i: 95
# (detierra,)
# PER
# Person!
# i: 97
# (enel,)
# PER
# Person!
# i: 99
# (sitiode,)
# ORG
# Not a person.
# i: 100
# i: 101
# (Bocachicajurisdicción,)
# LOC
# Not a person.
# i: 102
# i: 103
# i: 104
# i: 105
# i: 106
# i: 107
# (quehubo,)
# LOC
# Not a person.
# i: 108
# i: 109
# i: 110
# i: 111
# (ΠJavier,)
# MISC
# Not a person.
# i: 112
# (JavierSolano,)
# MISC
# Not a person.
# i: 113
# (Solanoy,)
# LOC
# Not a person.
# i: 114
# (yGregorio,)
# MISC
# Not a person.
# i: 115
# (GregorioMurillo,)
# MISC
# Not a person.
# i: 116
# (Murilloo,)
# ORG
# Not a person.
# i: 117
# i: 118
# (asu,)
# PER
# Person!
# i: 120
# (pr536)--Eso,)
# ORG
# Not a person.
# i: 121
# i: 122
# i: 123
# i: 124
# i: 125
# i: 126
# i: 127
# (juliode,)
# PER
# Person!
# i: 129
# i: 130
# i: 131
# i: 132
# (Númeroy,)
# LOC
# Not a person.
# i: 133
# i: 134
# (enla,)
# PER
# Person!
# i: 136
# (fechaqueda,)
# PER
# Person!
# i: 138
# (protocoladoel,)
# LOC
# Not a person.
# i: 139
# (eldocumento,)
# ORG
# Not a person.
# i: 140
# (documentoque,)
# LOC
# Not a person.
# i: 141
# (queAntonio,)
# MISC
# Not a person.
# i: 142
# (AntonioJosé,)
# MISC
# Not a person.
# i: 143
# (Joséde,)
# MISC
# Not a person.
# i: 144
# i: 145
# (Herreraotorgó,)
# PER
# Person!
# i: 147
# (aMateo,)
# MISC
# Not a person.
# i: 148
# (MateoMarón,)
# MISC
# Not a person.
# i: 149
# i: 150
# (yFrancisco,)
# MISC
# Not a person.
# i: 151
# (FranciscoJavier,)
# MISC
# Not a person.
# i: 152
# (JavierLeal,)
# LOC
# Not a person.
# i: 153
# i: 154
# i: 155
# (unaestancia,)
# LOC
# Not a person.
# i: 156
# (estanciaen,)
# PER
# Person!
# i: 158
# (elpáramo,)
# MISC
# Not a person.
# i: 159
# (páramodel,)
# PER
# Person!
# i: 161
# (Contentojurisdicción,)
# LOC
# Not a person.
# i: 162
# i: 163
# i: 164
# (Chiscasy,)
# PER
# Person!
# i: 166
# i: 167
# i: 168
# i: 169
# (ElCocuy,)
# LOC
# Not a person.
# i: 170
# i: 171
# i: 172
# i: 173
# (setiembrede,)
# LOC
# Not a person.
# i: 174
# i: 175
# (1807--Antonio,)
# ORG
# Not a person.
# i: 176
# (AntonioJosé,)
# MISC
# Not a person.
# i: 177
# (Joséde,)
# MISC
# Not a person.
# i: 178
# i: 179
# (Herrera,)
# PER
# Person!
# i: 181
# (aJosé,)
# MISC
# Not a person.
# i: 182
# (JoséMatero,)
# MISC
# Not a person.
# i: 183
# (MateroBurón,)
# LOC
# Not a person.
# i: 184
# (Buróny,)
# LOC
# Not a person.
# i: 185
# (yFrancisco,)
# MISC
# Not a person.
# i: 186
# (FranciscoJavier,)
# MISC
# Not a person.
# i: 187
# (JavierLeal,)
# LOC
# Not a person.
# i: 188
# i: 189
# (unaestancia,)
# LOC
# Not a person.
# i: 190
# i: 191
# (detierra,)
# PER
# Person!
# i: 193
# (enlos,)
# PER
# Person!
# i: 195
# (piramosque,)
# LOC
# Not a person.
# i: 196
# i: 197
# i: 198
# (Contentojurisdicción,)
# LOC
# Not a person.
# i: 199
# i: 200
# i: 201
# (éstaparroquia,)
# ORG
# Not a person.
# i: 202
# i: 203
# (laque,)
# PER
# Person!
# i: 205
# (hubode,)
# PER
# Person!
# i: 207
# (sudifunto,)
# LOC
# Not a person.
# i: 208
# i: 209
# (padreAntonio,)
# PER
# Person!
# i: 211
# (deHerre,)
# LOC
# Not a person.
# i: 212
# (Herreza,)
# LOC
# Not a person.
# i: 213
# i: 214
# i: 215
# i: 216
# i: 217
# i: 218
# i: 219
# (muycomido,)
# PER
# Person!
# i: 221
# (alas,)
# LOC
# Not a person.
# i: 222
# (lasorillas,)
# PER
# Person!
# i: 224
# (ypor,)
# PER
# Person!
# i: 226
# i: 227
# i: 228
# i: 229
# i: 230
# i: 231
# (palabras338)--Esc,)
# LOC
# Not a person.
# i: 232
# i: 233
# (#,)
# MISC
# Not a person.
# i: 234
# (ElCocuy,)
# LOC
# Not a person.
# i: 235
# i: 236
# i: 237
# i: 238
# (juliode,)
# PER
# Person!
# i: 240
# (1858--Juan,)
# MISC
# Not a person.
# i: 241
# (JuanToure,)
# MISC
# Not a person.
# i: 242
# (Toure,)
# MISC
# Not a person.
# i: 243
# (Miguel,)
# PER
# Person!
# i: 245
# i: 246
# (vendena,)
# LOC
# Not a person.
# i: 247
# (aCruz,)
# MISC
# Not a person.
# i: 248
# (CruzBarrera,)
# MISC
# Not a person.
# i: 249
# (Barrera,)
# PER
# Person!
# i: 251
# i: 252
# (detierra,)
# PER
# Person!
# i: 254
# (enel,)
# PER
# Person!
# i: 256
# i: 257
# (tiode,)
# ORG
# Not a person.
# i: 258
# i: 259
# i: 260
# (hoyade,)
# PER
# Person!
# i: 262
# i: 263
# i: 264
# i: 265
# (Guacmayas,)
# LOC
# Not a person.
# i: 266
# (lasque,)
# ORG
# Not a person.
# i: 267
# (quehubier,)
# LOC
# Not a person.
# i: 268
# i: 269
# i: 270
# i: 271
# (compraa,)
# PER
# Person!
# i: 273
# (DomingoCuchavara,)
# LOC
# Not a person.
# i: 274
# i: 275
# i: 276
# i: 277
# (ElCocuy,)
# LOC
# Not a person.
# i: 278
# (Cocuy26,)
# MISC
# Not a person.
# i: 279
# i: 280
# i: 281
# (juliode,)
# PER
# Person!
# i: 283
# i: 284
# (Barrera,)
# PER
# Person!
# i: 286
# (aJesús,)
# MISC
# Not a person.
# i: 287
# (JesúsPatiño,)
# ORG
# Not a person.
# i: 288
# (Patiño,)
# PER
# Person!
# i: 290
# (pedazode,)
# LOC
# Not a person.
# i: 291
# (detierra,)
# PER
# Person!
# i: 293
# (enel,)
# PER
# Person!
# i: 295
# (sitiode,)
# ORG
# Not a person.
# i: 296
# i: 297
# (laHoyn,)
# MISC
# Not a person.
# i: 298
# (Hoynd,)
# PER
# Person!
# i: 300
# (Chacones,)
# PER
# Person!
# i: 302
# (deGuacamyas,)
# MISC
# Not a person.
# i: 303
# (Guacamyas.el,)
# MISC
# Not a person.
# i: 304
# i: 305
# (quehubo,)
# LOC
# Not a person.
# i: 306
# i: 307
# i: 308
# (compraa,)
# PER
# Person!
# i: 310
# (Jesús,)
# PER
# Person!
# i: 312
# (Támara,)
# LOC
# Not a person.
# i: 313
# (yMiguel,)
# MISC
# Not a person.
# i: 314
# (MiguelChacón,)
# MISC
# Not a person.
# i: 315
# i: 316
# i: 317
# (#,)
# MISC
# Not a person.
# i: 318
# i: 319
# (ElCocuy,)
# LOC
# Not a person.
# i: 320
# (Cocuy26,)
# MISC
# Not a person.
# i: 321
# i: 322
# i: 323
# (juliode,)
# PER
# Person!
# i: 325
# i: 326
# (Muñoz,)
# PER
# Person!
# i: 328
# (vendea,)
# LOC
# Not a person.
# i: 329
# (aAntonio,)
# MISC
# Not a person.
# i: 330
# (AntonioHerrera,)
# MISC
# Not a person.
# i: 331
# (Herreraun,)
# PER
# Person!
# i: 333
# i: 334
# (detierra,)
# PER
# Person!
# i: 336
# (enel,)
# PER
# Person!
# i: 338
# (sitiodel,)
# LOC
# Not a person.
# i: 339
# i: 340
# i: 341
# (cerradode,)
# LOC
# Not a person.
# i: 342
# (delos,)
# LOC
# Not a person.
# i: 343
# i: 344
# i: 345
# i: 346
# (jurisdiccióndel,)
# PER
# Person!
# i: 348
# (Espinoel,)
# LOC
# Not a person.
# i: 349
# i: 350
# (mismoque,)
# LOC
# Not a person.
# i: 351
# (quele,)
# PER
# Person!

# %%
" ".join(modified_text)
# Out:
# "648 -62en el citio de la Loma donde se divide para Chiscote, laque hubo enel repartodel resguardo de Guacamayas.334)--Esc .292-- El Cocuy 25 de juliode 1858- Eleuterio y Julian Patriciovenden a Joaquín 1 aría Espinel el derechoy acción quea cadauno le correspondeen lastierras del Alizal,ycortade ra vereda do. laa Tapias jurisdicción de Chiscas, las que hubieronen el repartodel resguardo de índíjenas de dicho Chiscas.------355)--Esc #293-- El Cocuy 25 de juliode 1858 Juan Crisostomo Rodríguez, vendor a Gavino Largo un pedazo detierra enel sitio de Bocachica jurisdicción de la Capilla; el que hubo por compra Π Javier Solano y Gregorio Murillo o asu pr 536)--Eso . 294-- ElCocuy 25 de juliode 1858-- Con éste Número y enla fechaqueda protocolado el documento que Antonio José de Herreraotorgó a Mateo Marón y Francisco Javier Leal vendiendoles una estanciaen el páramodel Contento jurisdicción de Chiscasy Guicon 357)--Folio 512-- El Cocuy 1° de setiembre de 1807-- Antonio José de Herrera,vende a José Matero Burón y Francisco Javier Leal, una estancia detierra enlos piramos que sitan Contento jurisdicción de ésta parroquia laque hubode su difunto padreAntonio de Herre za Lovatón (este documento se encuentra muycomido a lasorillas ypor lo mismo le faltan muchas palabras 338)--Esc #295-- El Cocuy 25 de juliode 1858-- Juan Toure,y Miguel Chacón venden a Cruz Barrera,una suerte detierra enel si tio de la hoyade Chacón juridicción de Guacmayas, las que hubier ron por compraa Domingo Cuchavara 339)--Esc .296-- El Cocuy 26 de juliode 1858--Cruz Barrera,vende a Jesús Patiño,un pedazo detierra enel sitio de la Hoynd Chacones,jurisdicción de Guacamyas. el que hubo por compraa Jesús Támara, y Miguel Chacón 340)--Esc #. 297-- El Cocuy 26 de juliode 1858--Camila Muñoz,v vende a Antonio Herreraun derecho detierra enel sitio del en cerrado de los Carreños ' jurisdiccióndel Espino el mismo quele"

# %%
document_text = " ".join(modified_text)
print(document_text)
# Out:
# 648 -62en el citio de la Loma donde se divide para Chiscote, laque hubo enel repartodel resguardo de Guacamayas.334)--Esc .292-- El Cocuy 25 de juliode 1858- Eleuterio y Julian Patriciovenden a Joaquín 1 aría Espinel el derechoy acción quea cadauno le correspondeen lastierras del Alizal,ycortade ra vereda do. laa Tapias jurisdicción de Chiscas, las que hubieronen el repartodel resguardo de índíjenas de dicho Chiscas.------355)--Esc #293-- El Cocuy 25 de juliode 1858 Juan Crisostomo Rodríguez, vendor a Gavino Largo un pedazo detierra enel sitio de Bocachica jurisdicción de la Capilla; el que hubo por compra Π Javier Solano y Gregorio Murillo o asu pr 536)--Eso . 294-- ElCocuy 25 de juliode 1858-- Con éste Número y enla fechaqueda protocolado el documento que Antonio José de Herreraotorgó a Mateo Marón y Francisco Javier Leal vendiendoles una estanciaen el páramodel Contento jurisdicción de Chiscasy Guicon 357)--Folio 512-- El Cocuy 1° de setiembre de 1807-- Antonio José de Herrera,vende a José Matero Burón y Francisco Javier Leal, una estancia detierra enlos piramos que sitan Contento jurisdicción de ésta parroquia laque hubode su difunto padreAntonio de Herre za Lovatón (este documento se encuentra muycomido a lasorillas ypor lo mismo le faltan muchas palabras 338)--Esc #295-- El Cocuy 25 de juliode 1858-- Juan Toure,y Miguel Chacón venden a Cruz Barrera,una suerte detierra enel si tio de la hoyade Chacón juridicción de Guacmayas, las que hubier ron por compraa Domingo Cuchavara 339)--Esc .296-- El Cocuy 26 de juliode 1858--Cruz Barrera,vende a Jesús Patiño,un pedazo detierra enel sitio de la Hoynd Chacones,jurisdicción de Guacamyas. el que hubo por compraa Jesús Támara, y Miguel Chacón 340)--Esc #. 297-- El Cocuy 26 de juliode 1858--Camila Muñoz,v vende a Antonio Herreraun derecho detierra enel sitio del en cerrado de los Carreños ' jurisdiccióndel Espino el mismo quele

# %%
text = "Ana Maria y Julián Patricio se casaron hace diez años"
doc = nlp(text)
for ent in doc.ents:
    print(ent)
    print(ent.label_)
# Out:
# Ana Maria
# PER
# Julián Patricio
# PER
